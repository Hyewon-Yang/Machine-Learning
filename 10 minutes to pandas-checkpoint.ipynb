# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#object creation
s = pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20210102', periods=6)
dates
# Out:
# DatetimeIndex(['2021-01-02', '2021-01-03', '2021-01-04', '2021-01-05',
#                '2021-01-06', '2021-01-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2021-01-02 -1.449583  0.830991 -0.101232  0.617780
# 2021-01-03 -0.074925 -0.389332 -0.276167  0.450285
# 2021-01-04 -0.151763  0.757433 -0.587263 -0.889459
# 2021-01-05  0.567280  0.347800  0.375727  0.908480
# 2021-01-06 -0.524002 -2.564878 -0.062356 -0.268200
# 2021-01-07  1.212943 -0.307937 -0.088087  1.538560

# %%
df2 = pd.DataFrame({'A':1., 'B':pd.Timestamp('20210102'), 'C':pd.Series(1, index=list(range(4)), dtype='float32'), 'D':np.array([3]*4, dtype='int32'), 'E':pd.Categorical(["test", "train", "test", "train"]), 'F':'foo'})
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2021-01-02  1.0  3   test  foo
# 1  1.0 2021-01-02  1.0  3  train  foo
# 2  1.0 2021-01-02  1.0  3   test  foo
# 3  1.0 2021-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
#viewing data
df.tail()
df.tail(3)
df.head()
# Out:
#                    A         B         C         D
# 2021-01-02 -1.449583  0.830991 -0.101232  0.617780
# 2021-01-03 -0.074925 -0.389332 -0.276167  0.450285
# 2021-01-04 -0.151763  0.757433 -0.587263 -0.889459
# 2021-01-05  0.567280  0.347800  0.375727  0.908480
# 2021-01-06 -0.524002 -2.564878 -0.062356 -0.268200

# %%
df.index
# Out:
# DatetimeIndex(['2021-01-02', '2021-01-03', '2021-01-04', '2021-01-05',
#                '2021-01-06', '2021-01-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.values
# Out:
# array([[-1.44958312,  0.83099076, -0.10123208,  0.61777981],
#        [-0.07492512, -0.38933203, -0.27616746,  0.45028531],
#        [-0.15176257,  0.75743309, -0.58726276, -0.88945922],
#        [ 0.56728015,  0.34779966,  0.37572747,  0.90848008],
#        [-0.52400213, -2.56487794, -0.06235596, -0.26820039],
#        [ 1.21294292, -0.30793713, -0.08808733,  1.53855996]])

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.070008 -0.220987 -0.123230  0.392908
# std    0.913033  1.258349  0.314038  0.861826
# min   -1.449583 -2.564878 -0.587263 -0.889459
# 25%   -0.430942 -0.368983 -0.232434 -0.088579
# 50%   -0.113344  0.019931 -0.094660  0.534033
# 75%    0.406729  0.655025 -0.068789  0.835805
# max    1.212943  0.830991  0.375727  1.538560

# %%
df.T
# Out:
#    2021-01-02  2021-01-03  2021-01-04  2021-01-05  2021-01-06  2021-01-07
# A   -1.449583   -0.074925   -0.151763    0.567280   -0.524002    1.212943
# B    0.830991   -0.389332    0.757433    0.347800   -2.564878   -0.307937
# C   -0.101232   -0.276167   -0.587263    0.375727   -0.062356   -0.088087
# D    0.617780    0.450285   -0.889459    0.908480   -0.268200    1.538560

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2021-01-02  0.617780 -0.101232  0.830991 -1.449583
# 2021-01-03  0.450285 -0.276167 -0.389332 -0.074925
# 2021-01-04 -0.889459 -0.587263  0.757433 -0.151763
# 2021-01-05  0.908480  0.375727  0.347800  0.567280
# 2021-01-06 -0.268200 -0.062356 -2.564878 -0.524002
# 2021-01-07  1.538560 -0.088087 -0.307937  1.212943

# %%
df.sort_index(axis=0, ascending=False)
# Out:
#                    A         B         C         D
# 2021-01-07  1.212943 -0.307937 -0.088087  1.538560
# 2021-01-06 -0.524002 -2.564878 -0.062356 -0.268200
# 2021-01-05  0.567280  0.347800  0.375727  0.908480
# 2021-01-04 -0.151763  0.757433 -0.587263 -0.889459
# 2021-01-03 -0.074925 -0.389332 -0.276167  0.450285
# 2021-01-02 -1.449583  0.830991 -0.101232  0.617780

# %%
df.sort_values(by='B')
# Out:
#                    A         B         C         D
# 2021-01-06 -0.524002 -2.564878 -0.062356 -0.268200
# 2021-01-03 -0.074925 -0.389332 -0.276167  0.450285
# 2021-01-07  1.212943 -0.307937 -0.088087  1.538560
# 2021-01-05  0.567280  0.347800  0.375727  0.908480
# 2021-01-04 -0.151763  0.757433 -0.587263 -0.889459
# 2021-01-02 -1.449583  0.830991 -0.101232  0.617780

# %%
#selection
df['A']
# Out:
# 2021-01-02   -1.449583
# 2021-01-03   -0.074925
# 2021-01-04   -0.151763
# 2021-01-05    0.567280
# 2021-01-06   -0.524002
# 2021-01-07    1.212943
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2021-01-02 -1.449583  0.830991 -0.101232  0.617780
# 2021-01-03 -0.074925 -0.389332 -0.276167  0.450285
# 2021-01-04 -0.151763  0.757433 -0.587263 -0.889459

# %%
df['20210103':'20210105']
# Out:
#                    A         B         C         D
# 2021-01-03 -0.074925 -0.389332 -0.276167  0.450285
# 2021-01-04 -0.151763  0.757433 -0.587263 -0.889459
# 2021-01-05  0.567280  0.347800  0.375727  0.908480

# %%
df.loc[dates[0]]
# Out:
# A   -1.449583
# B    0.830991
# C   -0.101232
# D    0.617780
# Name: 2021-01-02 00:00:00, dtype: float64

# %%
df.loc[:, ['A','B']]
# Out:
#                    A         B
# 2021-01-02 -1.449583  0.830991
# 2021-01-03 -0.074925 -0.389332
# 2021-01-04 -0.151763  0.757433
# 2021-01-05  0.567280  0.347800
# 2021-01-06 -0.524002 -2.564878
# 2021-01-07  1.212943 -0.307937

# %%
df.loc['20210103':'20210105', ['A','B']]
# Out:
#                    A         B
# 2021-01-03 -0.074925 -0.389332
# 2021-01-04 -0.151763  0.757433
# 2021-01-05  0.567280  0.347800

# %%
df.loc['20210102',['A','B']]
# Out:
# A   -1.449583
# B    0.830991
# Name: 2021-01-02 00:00:00, dtype: float64

# %%
df.loc[dates[0],'A']
# Out:
# -1.4495831247904967

# %%
df.at[dates[0],'A']
# Out:
# -1.4495831247904967

# %%
df.iloc[3]
# Out:
# A    0.567280
# B    0.347800
# C    0.375727
# D    0.908480
# Name: 2021-01-05 00:00:00, dtype: float64

# %%
df.iloc[3:5,0:2]
# Out:
#                    A         B
# 2021-01-05  0.567280  0.347800
# 2021-01-06 -0.524002 -2.564878

# %%
df.iloc[[1,2,4],[0,2]]
# Out:
#                    A         C
# 2021-01-03 -0.074925 -0.276167
# 2021-01-04 -0.151763 -0.587263
# 2021-01-06 -0.524002 -0.062356

# %%
df.iloc[1:3,:]
# Out:
#                    A         B         C         D
# 2021-01-03 -0.074925 -0.389332 -0.276167  0.450285
# 2021-01-04 -0.151763  0.757433 -0.587263 -0.889459

# %%
df.iloc[:,1:3]
# Out:
#                    B         C
# 2021-01-02  0.830991 -0.101232
# 2021-01-03 -0.389332 -0.276167
# 2021-01-04  0.757433 -0.587263
# 2021-01-05  0.347800  0.375727
# 2021-01-06 -2.564878 -0.062356
# 2021-01-07 -0.307937 -0.088087

# %%
df.iloc[1,1]
# Out:
# -0.3893320277749676

# %%
df.iat[1,1]
# Out:
# -0.3893320277749676

# %%
df[df.A > 0]
# Out:
#                    A         B         C        D
# 2021-01-05  0.567280  0.347800  0.375727  0.90848
# 2021-01-07  1.212943 -0.307937 -0.088087  1.53856

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2021-01-02       NaN  0.830991       NaN  0.617780
# 2021-01-03       NaN       NaN       NaN  0.450285
# 2021-01-04       NaN  0.757433       NaN       NaN
# 2021-01-05  0.567280  0.347800  0.375727  0.908480
# 2021-01-06       NaN       NaN       NaN       NaN
# 2021-01-07  1.212943       NaN       NaN  1.538560

# %%
df2 = df.copy()
df2['E'] = ['one', 'one', 'two', 'three', 'four', 'three']
df2
# Out:
#                    A         B         C         D      E
# 2021-01-02 -1.449583  0.830991 -0.101232  0.617780    one
# 2021-01-03 -0.074925 -0.389332 -0.276167  0.450285    one
# 2021-01-04 -0.151763  0.757433 -0.587263 -0.889459    two
# 2021-01-05  0.567280  0.347800  0.375727  0.908480  three
# 2021-01-06 -0.524002 -2.564878 -0.062356 -0.268200   four
# 2021-01-07  1.212943 -0.307937 -0.088087  1.538560  three

# %%
df2[df2['E'].isin(['two','four'])]
# Out:
#                    A         B         C         D     E
# 2021-01-04 -0.151763  0.757433 -0.587263 -0.889459   two
# 2021-01-06 -0.524002 -2.564878 -0.062356 -0.268200  four

# %%
df2['E'].isin(['two','four'])
# Out:
# 2021-01-02    False
# 2021-01-03    False
# 2021-01-04     True
# 2021-01-05    False
# 2021-01-06     True
# 2021-01-07    False
# Freq: D, Name: E, dtype: bool

# %%
s1 = pd.Series([1,2,3,4,5,6], index=pd.date_range('20210102', periods=6))
s1
# Out:
# 2021-01-02    1
# 2021-01-03    2
# 2021-01-04    3
# 2021-01-05    4
# 2021-01-06    5
# 2021-01-07    6
# Freq: D, dtype: int64

# %%
df['F'] = s1
df
# Out:
#                    A         B         C         D  F
# 2021-01-02 -1.449583  0.830991 -0.101232  0.617780  1
# 2021-01-03 -0.074925 -0.389332 -0.276167  0.450285  2
# 2021-01-04 -0.151763  0.757433 -0.587263 -0.889459  3
# 2021-01-05  0.567280  0.347800  0.375727  0.908480  4
# 2021-01-06 -0.524002 -2.564878 -0.062356 -0.268200  5
# 2021-01-07  1.212943 -0.307937 -0.088087  1.538560  6

# %%
df.at[dates[0],'A'] = 0
df
# Out:
#                    A         B         C         D  F
# 2021-01-02  0.000000  0.830991 -0.101232  0.617780  1
# 2021-01-03 -0.074925 -0.389332 -0.276167  0.450285  2
# 2021-01-04 -0.151763  0.757433 -0.587263 -0.889459  3
# 2021-01-05  0.567280  0.347800  0.375727  0.908480  4
# 2021-01-06 -0.524002 -2.564878 -0.062356 -0.268200  5
# 2021-01-07  1.212943 -0.307937 -0.088087  1.538560  6

# %%
df.iat[0,1] = 0
df
# Out:
#                    A         B         C         D  F
# 2021-01-02  0.000000  0.000000 -0.101232  0.617780  1
# 2021-01-03 -0.074925 -0.389332 -0.276167  0.450285  2
# 2021-01-04 -0.151763  0.757433 -0.587263 -0.889459  3
# 2021-01-05  0.567280  0.347800  0.375727  0.908480  4
# 2021-01-06 -0.524002 -2.564878 -0.062356 -0.268200  5
# 2021-01-07  1.212943 -0.307937 -0.088087  1.538560  6

# %%
df.loc[:,'D'] = np.array([5]*len(df))
df
# Out:
#                    A         B         C  D  F
# 2021-01-02  0.000000  0.000000 -0.101232  5  1
# 2021-01-03 -0.074925 -0.389332 -0.276167  5  2
# 2021-01-04 -0.151763  0.757433 -0.587263  5  3
# 2021-01-05  0.567280  0.347800  0.375727  5  4
# 2021-01-06 -0.524002 -2.564878 -0.062356  5  5
# 2021-01-07  1.212943 -0.307937 -0.088087  5  6

# %%
df2 = df.copy()
df2[df2 > 0] = -df2
df2
# Out:
#                    A         B         C  D  F
# 2021-01-02  0.000000  0.000000 -0.101232 -5 -1
# 2021-01-03 -0.074925 -0.389332 -0.276167 -5 -2
# 2021-01-04 -0.151763 -0.757433 -0.587263 -5 -3
# 2021-01-05 -0.567280 -0.347800 -0.375727 -5 -4
# 2021-01-06 -0.524002 -2.564878 -0.062356 -5 -5
# 2021-01-07 -1.212943 -0.307937 -0.088087 -5 -6

# %%
#missing data
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ['E'])
df1.loc[dates[0]:dates[1], 'E'] = 1
df1
# Out:
#                    A         B         C  D  F    E
# 2021-01-02  0.000000  0.000000 -0.101232  5  1  1.0
# 2021-01-03 -0.074925 -0.389332 -0.276167  5  2  1.0
# 2021-01-04 -0.151763  0.757433 -0.587263  5  3  NaN
# 2021-01-05  0.567280  0.347800  0.375727  5  4  NaN

# %%
df1.dropna(how='any')
# Out:
#                    A         B         C  D  F    E
# 2021-01-02  0.000000  0.000000 -0.101232  5  1  1.0
# 2021-01-03 -0.074925 -0.389332 -0.276167  5  2  1.0

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C  D  F    E
# 2021-01-02  0.000000  0.000000 -0.101232  5  1  1.0
# 2021-01-03 -0.074925 -0.389332 -0.276167  5  2  1.0
# 2021-01-04 -0.151763  0.757433 -0.587263  5  3  5.0
# 2021-01-05  0.567280  0.347800  0.375727  5  4  5.0

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2021-01-02  False  False  False  False  False  False
# 2021-01-03  False  False  False  False  False  False
# 2021-01-04  False  False  False  False  False   True
# 2021-01-05  False  False  False  False  False   True

# %%
#operation
df.mean()
# Out:
# A    0.171589
# B   -0.359486
# C   -0.123230
# D    5.000000
# F    3.500000
# dtype: float64

# %%
df.mean(1)
# Out:
# 2021-01-02    1.179754
# 2021-01-03    1.251915
# 2021-01-04    1.603682
# 2021-01-05    2.058161
# 2021-01-06    1.369753
# 2021-01-07    2.363384
# Freq: D, dtype: float64

# %%
s = pd.Series([1,3,5,np.nan,6,8], index=dates).shift(2)
s
# Out:
# 2021-01-02    NaN
# 2021-01-03    NaN
# 2021-01-04    1.0
# 2021-01-05    3.0
# 2021-01-06    5.0
# 2021-01-07    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis='index')
# Out:
#                    A         B         C    D    F
# 2021-01-02       NaN       NaN       NaN  NaN  NaN
# 2021-01-03       NaN       NaN       NaN  NaN  NaN
# 2021-01-04 -1.151763 -0.242567 -1.587263  4.0  2.0
# 2021-01-05 -2.432720 -2.652200 -2.624273  2.0  1.0
# 2021-01-06 -5.524002 -7.564878 -5.062356  0.0  0.0
# 2021-01-07       NaN       NaN       NaN  NaN  NaN

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C   D   F
# 2021-01-02  0.000000  0.000000 -0.101232   5   1
# 2021-01-03 -0.074925 -0.389332 -0.377400  10   3
# 2021-01-04 -0.226688  0.368101 -0.964662  15   6
# 2021-01-05  0.340592  0.715901 -0.588935  20  10
# 2021-01-06 -0.183410 -1.848977 -0.651291  25  15
# 2021-01-07  1.029533 -2.156914 -0.739378  30  21

# %%
df
df.apply(lambda x: x.max() - x.min())
# Out:
# A    1.736945
# B    3.322311
# C    0.962990
# D    0.000000
# F    5.000000
# dtype: float64

# %%
s = pd.Series(np.random.randint(0, 7, size=10))
s
# Out:
# 0    1
# 1    2
# 2    4
# 3    4
# 4    5
# 5    0
# 6    2
# 7    4
# 8    0
# 9    1
# dtype: int32

# %%
s.value_counts()
# Out:
# 4    3
# 2    2
# 1    2
# 0    2
# 5    1
# dtype: int64

# %%
s = pd.Series(['A', 'B', 'C', 'Aaba', 'Baca', np.nan, 'CABA', 'dog', 'cat'])
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
#merge
df = pd.DataFrame(np.random.randn(10, 4))
df
# Out:
#           0         1         2         3
# 0  0.897387 -1.340362  0.154876 -0.035724
# 1  0.713749  0.589501 -0.963582  0.614449
# 2  0.155482  1.126419  1.218986  1.110205
# 3 -0.599330 -0.072777 -1.621280 -2.328723
# 4  0.576986 -0.823663  0.355231  0.063033
# 5 -0.392510  0.151715 -0.896313  1.597015
# 6  0.172404  2.643462 -0.166124  1.288960
# 7 -0.026128 -0.889745  0.360840 -0.922725
# 8 -0.150809 -0.613831  0.725281  0.384232
# 9 -1.173493  1.056814  0.613007 -1.581670

# %%
pieces = [df[:3], df[3:7], df[7:]]
pieces
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  0.897387 -1.340362  0.154876 -0.035724
# 1  0.713749  0.589501 -0.963582  0.614449
# 2  0.155482  1.126419  1.218986  1.110205
# 3 -0.599330 -0.072777 -1.621280 -2.328723
# 4  0.576986 -0.823663  0.355231  0.063033
# 5 -0.392510  0.151715 -0.896313  1.597015
# 6  0.172404  2.643462 -0.166124  1.288960
# 7 -0.026128 -0.889745  0.360840 -0.922725
# 8 -0.150809 -0.613831  0.725281  0.384232
# 9 -1.173493  1.056814  0.613007 -1.581670

# %%
left = pd.DataFrame({'key': ['foo', 'foo'], 'lval': [1, 2]})
right = pd.DataFrame({'key': ['foo', 'foo'], 'rval': [4, 5]})
left
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on= 'key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
left = pd.DataFrame({'key': ['foo', 'bar'], 'lval': [1, 2]})
right = pd.DataFrame({'key': ['foo', 'bar'], 'rval': [4, 5]})
left
right
pd.merge(left, right, on= 'key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns=['A', 'B', 'C', 'D'])
df
# Out:
#           A         B         C         D
# 0  0.544125 -0.941553 -0.756503  0.974886
# 1 -1.517190 -0.543087  0.032185  0.686271
# 2  1.391759 -1.098116 -0.180427 -0.253281
# 3  0.898380  0.043826 -0.400996  1.678386
# 4 -0.189528 -0.991986  1.067068 -0.025790
# 5  0.603661 -0.278774 -0.935713 -0.449761
# 6 -0.371115 -0.868403  0.080663 -1.687613
# 7 -0.155211 -1.858358  1.211598  0.114623

# %%
s = df.iloc[3]
df.append(s, ignore_index=True)
# Out:
#           A         B         C         D
# 0  0.544125 -0.941553 -0.756503  0.974886
# 1 -1.517190 -0.543087  0.032185  0.686271
# 2  1.391759 -1.098116 -0.180427 -0.253281
# 3  0.898380  0.043826 -0.400996  1.678386
# 4 -0.189528 -0.991986  1.067068 -0.025790
# 5  0.603661 -0.278774 -0.935713 -0.449761
# 6 -0.371115 -0.868403  0.080663 -1.687613
# 7 -0.155211 -1.858358  1.211598  0.114623
# 8  0.898380  0.043826 -0.400996  1.678386

# %%
#grouping
df = pd.DataFrame({
    'A' : ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
    'B' : ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
    'C' : np.random.randn(8),
    'D' : np.random.randn(8)
})
df
# Out:
#      A      B         C         D
# 0  foo    one -0.481464  0.302010
# 1  bar    one -1.278666 -0.291880
# 2  foo    two  0.635651 -0.389265
# 3  bar  three -0.410587  0.647128
# 4  foo    two  0.438569 -0.242346
# 5  bar    two -1.431816 -0.933701
# 6  foo    one  1.525343  0.174573
# 7  foo  three  1.923622  0.339907

# %%
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar -3.121068 -0.578453
# foo  4.041721  0.184880

# %%
df.groupby(['A', 'B']).sum()
# Out:
#                   C         D
# A   B
# bar one   -1.278666 -0.291880
#     three -0.410587  0.647128
#     two   -1.431816 -0.933701
# foo one    1.043879  0.476584
#     three  1.923622  0.339907
#     two    1.074219 -0.631611

# %%
#reshaping
tuples = list(zip(*[['bar', 'bar', 'baz', 'baz',
                     'foo', 'foo', 'qux', 'qux'],
                    ['one', 'two', 'one', 'two',
                     'one', 'two', 'one', 'two']]))
tuples
# Out:
# [('bar', 'one'),
#  ('bar', 'two'),
#  ('baz', 'one'),
#  ('baz', 'two'),
#  ('foo', 'one'),
#  ('foo', 'two'),
#  ('qux', 'one'),
#  ('qux', 'two')]

# %%
index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])
index
# Out:
# MultiIndex(levels=[['bar', 'baz', 'foo', 'qux'], ['one', 'two']],
#            codes=[[0, 0, 1, 1, 2, 2, 3, 3], [0, 1, 0, 1, 0, 1, 0, 1]],
#            names=['first', 'second'])

# %%
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=['A', 'B'])
df
# Out:
#                      A         B
# first second
# bar   one     0.528840  0.465382
#       two     0.266536 -1.108981
# baz   one    -2.023229  0.691205
#       two    -0.136761 -1.909132
# foo   one     1.382972  0.395062
#       two     0.022060 -1.836221
# qux   one    -1.490672 -1.432054
#       two    -0.286474  1.889086

# %%
df2 = df[:4]
df2
# Out:
#                      A         B
# first second
# bar   one     0.528840  0.465382
#       two     0.266536 -1.108981
# baz   one    -2.023229  0.691205
#       two    -0.136761 -1.909132

# %%
stacked = df2.stack()
stacked
# Out:
# first  second
# bar    one     A    0.528840
#                B    0.465382
#        two     A    0.266536
#                B   -1.108981
# baz    one     A   -2.023229
#                B    0.691205
#        two     A   -0.136761
#                B   -1.909132
# dtype: float64

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one     0.528840  0.465382
#       two     0.266536 -1.108981
# baz   one    -2.023229  0.691205
#       two    -0.136761 -1.909132

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A  0.528840  0.266536
#       B  0.465382 -1.108981
# baz   A -2.023229 -0.136761
#       B  0.691205 -1.909132

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A  0.528840 -2.023229
#        B  0.465382  0.691205
# two    A  0.266536 -0.136761
#        B -1.108981 -1.909132

# %%
df = pd.DataFrame({'A' : ['one', 'one', 'two', 'three'] * 3,
                   'B' : ['A', 'B', 'C'] * 4,
                   'C' : ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
                   'D' : np.random.randn(12),
                   'E' : np.random.randn(12)})
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo  0.124608 -0.949478
# 1     one  B  foo  0.153582  0.294295
# 2     two  C  foo  1.089848  0.473246
# 3   three  A  bar -0.832570 -0.003208
# 4     one  B  bar -0.695215 -0.423433
# 5     one  C  bar  1.788509  0.368182
# 6     two  A  foo  1.220183  1.613942
# 7   three  B  foo -0.054163 -0.347000
# 8     one  C  foo -0.372137 -0.408017
# 9     one  A  bar -1.245441  1.823094
# 10    two  B  bar -1.745873  0.826689
# 11  three  C  bar  1.465374 -0.487241

# %%
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])
# Out:
# C             bar       foo
# A     B
# one   A -1.245441  0.124608
#       B -0.695215  0.153582
#       C  1.788509 -0.372137
# three A -0.832570       NaN
#       B       NaN -0.054163
#       C  1.465374       NaN
# two   A       NaN  1.220183
#       B -1.745873       NaN
#       C       NaN  1.089848

# %%
#time series
rng = pd.date_range('1/1/2021', periods=100, freq='S')
rng
# Out:
# DatetimeIndex(['2021-01-01 00:00:00', '2021-01-01 00:00:01',
#                '2021-01-01 00:00:02', '2021-01-01 00:00:03',
#                '2021-01-01 00:00:04', '2021-01-01 00:00:05',
#                '2021-01-01 00:00:06', '2021-01-01 00:00:07',
#                '2021-01-01 00:00:08', '2021-01-01 00:00:09',
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)
ts
# Out:
# 2021-01-01 00:00:00    247
# 2021-01-01 00:00:01     38
# 2021-01-01 00:00:02    247
# 2021-01-01 00:00:03    272
# 2021-01-01 00:00:04     96
# 2021-01-01 00:00:05    179
# 2021-01-01 00:00:06    495
# 2021-01-01 00:00:07    435
# 2021-01-01 00:00:08     72
# 2021-01-01 00:00:09     61
# 2021-01-01 00:00:10    171
# 2021-01-01 00:00:11    412
# 2021-01-01 00:00:12    118
# 2021-01-01 00:00:13    248
# 2021-01-01 00:00:14    465
# 2021-01-01 00:00:15    390
# 2021-01-01 00:00:16    265
# 2021-01-01 00:00:17     78
# 2021-01-01 00:00:18    324
# 2021-01-01 00:00:19    338
# 2021-01-01 00:00:20    401
# 2021-01-01 00:00:21    270
# 2021-01-01 00:00:22    364
# 2021-01-01 00:00:23    377
# 2021-01-01 00:00:24     29
# 2021-01-01 00:00:25    483
# 2021-01-01 00:00:26     18
# 2021-01-01 00:00:27    153
# 2021-01-01 00:00:28    368
# 2021-01-01 00:00:29    315
#                       ...
# 2021-01-01 00:01:10    468
# 2021-01-01 00:01:11    113
# 2021-01-01 00:01:12     37
# 2021-01-01 00:01:13    182
# 2021-01-01 00:01:14     42
# 2021-01-01 00:01:15    138
# 2021-01-01 00:01:16     93
# 2021-01-01 00:01:17     79
# 2021-01-01 00:01:18    248
# 2021-01-01 00:01:19     92
# 2021-01-01 00:01:20    442
# 2021-01-01 00:01:21     22
# 2021-01-01 00:01:22    485
# 2021-01-01 00:01:23    430
# 2021-01-01 00:01:24    395
# 2021-01-01 00:01:25    492
# 2021-01-01 00:01:26    179
# 2021-01-01 00:01:27    113
# 2021-01-01 00:01:28    375
# 2021-01-01 00:01:29    346
# 2021-01-01 00:01:30     75
# 2021-01-01 00:01:31     93
# 2021-01-01 00:01:32    251
# 2021-01-01 00:01:33    345
# 2021-01-01 00:01:34    253
# 2021-01-01 00:01:35    326
# 2021-01-01 00:01:36    374
# 2021-01-01 00:01:37     60
# 2021-01-01 00:01:38    316
# 2021-01-01 00:01:39      8
# Freq: S, Length: 100, dtype: int32

# %%
ts.resample('5Min').sum()
# Out:
# 2021-01-01    24868
# Freq: 5T, dtype: int32

# %%
rng = pd.date_range('3/6/2021 00:00', periods=5, freq='D')
ts = pd.Series(np.random.randn(len(rng)), rng)
ts
# Out:
# 2021-03-06    0.199102
# 2021-03-07    0.614783
# 2021-03-08    0.181201
# 2021-03-09   -0.168474
# 2021-03-10    0.289343
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize('UTC')
ts_utc
# Out:
# 2021-03-06 00:00:00+00:00    0.199102
# 2021-03-07 00:00:00+00:00    0.614783
# 2021-03-08 00:00:00+00:00    0.181201
# 2021-03-09 00:00:00+00:00   -0.168474
# 2021-03-10 00:00:00+00:00    0.289343
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert('US/Eastern')
# Out:
# 2021-03-05 19:00:00-05:00    0.199102
# 2021-03-06 19:00:00-05:00    0.614783
# 2021-03-07 19:00:00-05:00    0.181201
# 2021-03-08 19:00:00-05:00   -0.168474
# 2021-03-09 19:00:00-05:00    0.289343
# Freq: D, dtype: float64

# %%
rng = pd.date_range('1/2/2021', periods=5, freq='M')
ts = pd.Series(np.random.randn(len(rng)), index=rng)
ts
# Out:
# 2021-01-31    1.477334
# 2021-02-28    0.311454
# 2021-03-31   -1.220563
# 2021-04-30    0.160633
# 2021-05-31   -1.433892
# Freq: M, dtype: float64

# %%
ps = ts.to_period()
ps
# Out:
# 2021-01    1.477334
# 2021-02    0.311454
# 2021-03   -1.220563
# 2021-04    0.160633
# 2021-05   -1.433892
# Freq: M, dtype: float64

# %%
ps.to_timestamp()
# Out:
# 2021-01-01    1.477334
# 2021-02-01    0.311454
# 2021-03-01   -1.220563
# 2021-04-01    0.160633
# 2021-05-01   -1.433892
# Freq: MS, dtype: float64

# %%
prng = pd.period_range('1990Q1', '2000Q4', freq='Q-NOV')
ts = pd.Series(np.random.randn(len(prng)), prng)
ts.index = (prng.asfreq('M', 'e') + 1).asfreq('H', 's') + 9
ts.head()
# Out:
# 1990-03-01 09:00    0.302856
# 1990-06-01 09:00    0.070838
# 1990-09-01 09:00   -1.144329
# 1990-12-01 09:00    1.636232
# 1991-03-01 09:00    0.565079
# Freq: H, dtype: float64

# %%
#categoricals
df = pd.DataFrame({"id":[1,2,3,4,5,6], "raw_grade":['a', 'b', 'b', 'a', 'a', 'e']})
df
# Out:
#    id raw_grade
# 0   1         a
# 1   2         b
# 2   3         b
# 3   4         a
# 4   5         a
# 5   6         e

# %%
df["grade"] = df["raw_grade"].astype("category")
df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): [a, b, e]

# %%
df["grade"].cat.categories = ["very good", "good", "very bad"]

# %%
df["grade"] = df["grade"].cat.set_categories(["very bad", "bad", "medium", "good", "very good"])
df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): [very bad, bad, medium, good, very good]

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
df.groupby("grade").size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %%
#plotting
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2021', periods=1000))
ts = ts.cumsum()
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=['A', 'B', 'C', 'D'])
df = df.cumsum()
plt.figure(); df.plot(); plt.legend(loc='best')

# %%
#getting data in/out
df.to_csv('foo.csv')
pd.read_csv('foo.csv')
# Out:
#      Unnamed: 0          A          B          C          D
# 0    2021-01-01  -0.686438  -0.039052  -0.621426   1.495813
# 1    2021-01-02  -0.470286   0.818953  -2.171893   2.328929
# 2    2021-01-03  -1.157653  -0.017833  -2.622254   1.849391
# 3    2021-01-04  -1.196338   2.195911  -2.294994   2.379386
# 4    2021-01-05  -1.705341   3.582195  -2.865570   1.737968
# 5    2021-01-06  -0.984390   3.630860  -2.040226   0.935899
# 6    2021-01-07  -0.138387   3.207396  -2.925374  -0.211165
# 7    2021-01-08  -1.049231   2.152023  -1.811302  -0.525030
